# %%
# Import libraries
import warnings
import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Defaults
plt.rcParams['figure.figsize'] = (20.0, 10.0)
plt.rcParams.update({'font.size': 12})
plt.style.use('ggplot')

# %%
# Load the data
data = pd.read_excel('dataset/ari.xlsx', skipfooter=3)
# A bit of pre-processing to make it nicer
data['tanggal']=pd.to_datetime(data['tanggal'], format='%Y-%m-%d')
data.set_index(['tanggal'], inplace=True)

# Plot the data
data.plot()
plt.ylabel('Cargo')
plt.xlabel('Date')
plt.show()

# %%
# Define the d and q parameters to take any value between 0 and 1
q = d = range(0, 2)
# Define the p parameters to take any value between 0 and 3
p = range(0, 4)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
train_data = data['2018-01-01':'2019-06-01']
test_data = data['2019-07-01':'2019-12-01']

# %%
warnings.filterwarnings("ignore") # specify to ignore warning messages

AIC = []
SARIMAX_model = []
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(train_data,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('SARIMAX{}x{} - AIC:{}'.format(param, param_seasonal, results.aic), end='\r')
            AIC.append(results.aic)
            SARIMAX_model.append([param, param_seasonal])
        except:
            continue
# Out:
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.03760D+01    |proj g|=  1.28608D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   1.286D-07   1.038D+01
#   F =   10.375960761315742
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE, 12) - AIC:10730.743427200478
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00393D+01    |proj g|=  6.54777D-01
#
# At iterate    5    f=  9.85718D+00    |proj g|=  1.23637D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      7      9      1     0     0   6.812D-05   9.857D+00
#   F =   9.8571814701998548
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE, 12) - AIC:10196.32564018665
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.20182D+00    |proj g|=  6.26308D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   6.263D-06   9.202D+00
#   F =   9.2018248313243429
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE, 12) - AIC:9516.68687558937
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.75613D+00    |proj g|=  2.20391D-02
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate    5    f=  8.75597D+00    |proj g|=  1.46114D-03
#
# At iterate   10    f=  8.75561D+00    |proj g|=  3.20359D-02
#
# At iterate   15    f=  8.74442D+00    |proj g|=  4.79409D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     18     23      1     0     0   2.394D-06   8.744D+00
#   F =   8.7437118950205743
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE, 12) - AIC:9044.998099451273
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.20151D+00    |proj g|=  3.46096D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     14      1     0     0   3.452D-05   9.202D+00
#   F =   9.2015119502685039
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# SARIMAX(0, 0, 0)x(1, 0, 0, 12) - AIC:9518.363356577633
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.48391D+00    |proj g|=  2.19404D+01
#
# At iterate    5    f=  9.08626D+00    |proj g|=  2.14110D+00
#
# At iterate   10    f=  9.03184D+00    |proj g|=  2.85794D-01
#
# At iterate   15    f=  9.03082D+00    |proj g|=  1.17389D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     15     18      1     0     0   1.174D-05   9.031D+00
#   F =   9.0308168702516838
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE, 12) - AIC:9343.864643840241
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.87773D+00    |proj g|=  6.09077D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   6.091D-06   8.878D+00
#   F =   8.8777319917960593
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# SARIMAX(0, 0, 0)x(1, 1, 0, 12) - AIC:9183.574879517126
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.76351D+00    |proj g|=  8.74462D-02
#
# At iterate    5    f=  8.75284D+00    |proj g|=  6.55543D-05
#
# At iterate   10    f=  8.75284D+00    |proj g|=  1.80746D-03
#
# At iterate   15    f=  8.75231D+00    |proj g|=  2.13581D-02
#
# At iterate   20    f=  8.74388D+00    |proj g|=  2.22142D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     23     26      1     0     0   1.130D-06   8.744D+00
#   F =   8.7436918835882693
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE, 12) - AIC:9046.977407630271
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.86761D+00    |proj g|=  4.29743D-05
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      1     13      1     0     0   4.297D-05   8.868D+00
#   F =   8.8676139222210164
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.81817D+00    |proj g|=  3.32651D+00
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
# At iterate    5    f=  8.76959D+00    |proj g|=  5.69627D-01
#
# At iterate   10    f=  8.76616D+00    |proj g|=  6.16559D-02
#
# At iterate   15    f=  8.76356D+00    |proj g|=  1.58488D-01
#
# At iterate   20    f=  8.76319D+00    |proj g|=  5.46578D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     21     25      1     0     0   3.808D-05   8.763D+00
#   F =   8.7631887642555650
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE, 12) - AIC:9069.137182240254
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.56565D+00    |proj g|=  7.21467D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      0      1      0     0     0   7.215D-06   8.566D+00
#   F =   8.5656514656889957
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.54802D+00    |proj g|=  6.38945D-02
#  This problem is unconstrained.
# At iterate    5    f=  8.52869D+00    |proj g|=  1.18233D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      8     11      1     0     0   3.462D-05   8.529D+00
#   F =   8.5286747319249265
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE, 12) - AIC:8826.649672810374
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.56009D+00    |proj g|=  5.10099D-05
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      1     17      1     0     0   5.086D-05   8.560D+00
#   F =   8.5600937568334530
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# SARIMAX(0, 0, 0)x(3, 0, 0, 12) - AIC:8859.136944565791
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.53943D+00    |proj g|=  5.83045D-01
#
# At iterate    5    f=  8.53213D+00    |proj g|=  3.12692D-01
#
# At iterate   10    f=  8.52977D+00    |proj g|=  3.91548D-02
#
# At iterate   15    f=  8.52796D+00    |proj g|=  1.38382D-01
#
# At iterate   20    f=  8.52767D+00    |proj g|=  3.90003D-02
#
# At iterate   25    f=  8.52744D+00    |proj g|=  1.32657D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     26     29      1     0     0   3.526D-05   8.527D+00
#   F =   8.5274424148383350
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE, 12) - AIC:8827.375456942838
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.33010D+00    |proj g|=  7.44649D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      0      1      0     0     0   7.446D-06   8.330D+00
#   F =   8.3301008088491511
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE, 12) - AIC:8621.324236350023
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.33136D+00    |proj g|=  2.41774D-02
#  This problem is unconstrained.
# At iterate    5    f=  8.33101D+00    |proj g|=  5.81096D-03
#
# At iterate   10    f=  8.32370D+00    |proj g|=  1.17365D-01
#
# At iterate   15    f=  8.29868D+00    |proj g|=  1.72128D-02
#
# At iterate   20    f=  8.29851D+00    |proj g|=  3.86207D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     20     37      1     0     0   3.862D-05   8.299D+00
#   F =   8.2985100643716905
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE, 12) - AIC:8590.659406560328
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.01143D+01    |proj g|=  2.86318D-01
#
# At iterate    5    f=  1.00615D+01    |proj g|=  2.53040D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      7     10      1     0     0   9.216D-05   1.006D+01
#   F =   10.061530654762787
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE, 12) - AIC:10407.622697024723
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.83308D+00    |proj g|=  3.06264D-01
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate    5    f=  9.75886D+00    |proj g|=  4.11185D-04
#
# At iterate   10    f=  9.75796D+00    |proj g|=  2.16474D-02
#
# At iterate   15    f=  9.68169D+00    |proj g|=  3.26723D-01
#
# At iterate   20    f=  9.49397D+00    |proj g|=  1.20183D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     22     31      1     0     0   5.068D-06   9.494D+00
#   F =   9.4939719030771563
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE, 12) - AIC:9822.76694778178
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.15741D+00    |proj g|=  3.17269D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      6      1     0     0   1.346D-07   9.157D+00
#   F =   9.1570286298607417
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE, 12) - AIC:9472.367603276007
#
#            * * *
#  This problem is unconstrained.
#  This problem is unconstrained.
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.75552D+00    |proj g|=  2.51254D-02
#
# At iterate    5    f=  8.75523D+00    |proj g|=  1.29048D-04
#
# At iterate   10    f=  8.75522D+00    |proj g|=  2.97461D-03
#
# At iterate   15    f=  8.75407D+00    |proj g|=  3.49764D-02
#
# At iterate   20    f=  8.70586D+00    |proj g|=  1.28247D-01
#
# At iterate   25    f=  8.69859D+00    |proj g|=  3.17584D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     26     28      1     0     0   3.799D-06   8.699D+00
#   F =   8.6985885716741027
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE, 12) - AIC:9000.340583111023
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.73055D+00    |proj g|=  5.43201D-02
#
# At iterate    5    f=  9.72488D+00    |proj g|=  1.07525D-04
#  This problem is unconstrained.
# At iterate   10    f=  9.72487D+00    |proj g|=  1.16561D-03
#
# At iterate   15    f=  9.72461D+00    |proj g|=  1.47681D-02
#
# At iterate   20    f=  9.69102D+00    |proj g|=  2.10992D-01
#
# At iterate   25    f=  9.20232D+00    |proj g|=  4.37284D-01
#
# At iterate   30    f=  9.16824D+00    |proj g|=  3.52704D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     31     37      1     0     0   7.680D-06   9.168D+00
#   F =   9.1682392777192394
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE, 12) - AIC:9485.959413161694
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.70731D+00    |proj g|=  1.31947D+00
#  This problem is unconstrained.
# At iterate    5    f=  9.67414D+00    |proj g|=  1.03046D-01
#
# At iterate   10    f=  9.66863D+00    |proj g|=  5.38487D-03
#
# At iterate   15    f=  9.66859D+00    |proj g|=  1.11656D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     15     18      1     0     0   1.117D-04   9.669D+00
#   F =   9.6685875957769518
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE, 12) - AIC:10005.319574033369
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.86314D+00    |proj g|=  1.49374D-02
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      3      5      1     0     0   7.556D-05   8.863D+00
#   F =   8.8629990346583867
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE, 12) - AIC:9170.341001836772
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.76044D+00    |proj g|=  6.10206D-02
#  This problem is unconstrained.
# At iterate    5    f=  8.75459D+00    |proj g|=  1.28740D-04
#
# At iterate   10    f=  8.75459D+00    |proj g|=  1.74744D-03
#
# At iterate   15    f=  8.75416D+00    |proj g|=  2.23303D-02
#
# At iterate   20    f=  8.72807D+00    |proj g|=  1.91403D-01
#
# At iterate   25    f=  8.69847D+00    |proj g|=  9.46183D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     27     29      1     0     0   5.331D-05   8.698D+00
#   F =   8.6984703638860168
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE, 12) - AIC:9002.218356258141
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.48346D+00    |proj g|=  3.51184D-02
#
# At iterate    5    f=  9.48000D+00    |proj g|=  1.08479D-04
#  This problem is unconstrained.
# At iterate   10    f=  9.47998D+00    |proj g|=  2.85860D-03
#
# At iterate   15    f=  9.47812D+00    |proj g|=  2.18334D-02
#
# At iterate   20    f=  9.33277D+00    |proj g|=  2.07185D-01
#
# At iterate   25    f=  8.83684D+00    |proj g|=  1.53039D-01
#
# At iterate   30    f=  8.83492D+00    |proj g|=  1.02288D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     31     49      1     0     0   6.100D-07   8.835D+00
#   F =   8.8349188289626657
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# SARIMAX(0, 0, 1)x(2, 0, 0, 12) - AIC:9143.306069147397
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.47937D+00    |proj g|=  1.73260D-01
#
# At iterate    5    f=  9.47409D+00    |proj g|=  6.41434D-02
#
# At iterate   10    f=  9.47223D+00    |proj g|=  1.11509D-02
#
# At iterate   15    f=  9.47214D+00    |proj g|=  2.20447D-03
#
# At iterate   20    f=  9.47213D+00    |proj g|=  1.10514D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     22     24      1     0     0   1.152D-04   9.472D+00
#   F =   9.4721319481479362
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# SARIMAX(0, 0, 1)x(2, 0, 1, 12) - AIC:9804.184434384966
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.58745D+00    |proj g|=  3.08494D-02
#
# At iterate    5    f=  8.58666D+00    |proj g|=  1.14664D-04
#
# At iterate   10    f=  8.58665D+00    |proj g|=  2.42250D-03
#
# At iterate   15    f=  8.58512D+00    |proj g|=  2.85605D-02
#
# At iterate   20    f=  8.54576D+00    |proj g|=  2.51435D-02
#
# At iterate   25    f=  8.54527D+00    |proj g|=  2.45475D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     25     29      1     0     0   2.455D-06   8.545D+00
#   F =   8.5452708315232329
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE, 12) - AIC:8843.810039795022
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.57672D+00    |proj g|=  3.82619D-02
#  This problem is unconstrained.
# At iterate    5    f=  8.56565D+00    |proj g|=  1.48231D-02
#
# At iterate   10    f=  8.56533D+00    |proj g|=  1.30768D-04
#
# At iterate   15    f=  8.56532D+00    |proj g|=  1.74236D-03
#
# At iterate   20    f=  8.56388D+00    |proj g|=  2.11342D-02
#
# At iterate   25    f=  8.52252D+00    |proj g|=  1.01245D-01
#
# At iterate   30    f=  8.50565D+00    |proj g|=  2.52315D-02
#
# At iterate   35    f=  8.50507D+00    |proj g|=  2.05997D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     36     55      1     0     0   7.068D-05   8.505D+00
#   F =   8.5050705376728928
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE, 12) - AIC:8804.242935953771
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.24558D+00    |proj g|=  3.59304D-02
#  This problem is unconstrained.
# At iterate    5    f=  9.24139D+00    |proj g|=  3.96718D-04
#
# At iterate   10    f=  9.24139D+00    |proj g|=  2.03912D-04
#
# At iterate   15    f=  9.24137D+00    |proj g|=  3.25177D-03
#
# At iterate   20    f=  9.24061D+00    |proj g|=  1.80110D-02
#
# At iterate   25    f=  9.15747D+00    |proj g|=  2.01190D-01
#
# At iterate   30    f=  8.55603D+00    |proj g|=  4.44222D-01
#
# At iterate   35    f=  8.53891D+00    |proj g|=  2.33483D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     36     46      1     0     0   4.573D-06   8.539D+00
#   F =   8.5389073001312141
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# SARIMAX(0, 0, 1)x(3, 0, 0, 12) - AIC:8839.230148335675
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.24422D+00    |proj g|=  3.31313D-02
#
# At iterate    5    f=  9.23923D+00    |proj g|=  1.05773D-03
#
# At iterate   10    f=  9.23920D+00    |proj g|=  1.46506D-04
#
# At iterate   15    f=  9.23919D+00    |proj g|=  3.87343D-04
#
# At iterate   20    f=  9.23864D+00    |proj g|=  7.43846D-03
#
# At iterate   25    f=  9.18685D+00    |proj g|=  7.01043D-02
#
# At iterate   30    f=  8.72979D+00    |proj g|=  1.67211D+00
#
# At iterate   35    f=  8.50917D+00    |proj g|=  6.47801D-02
#
# At iterate   40    f=  8.50868D+00    |proj g|=  1.29490D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     42     59      1     0     0   1.175D-05   8.509D+00
#   F =   8.5086840127913046
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE, 12) - AIC:8809.979269226209
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.36104D+00    |proj g|=  3.63830D-02
#  This problem is unconstrained.
# At iterate    5    f=  8.36005D+00    |proj g|=  1.20185D-04
#
# At iterate   10    f=  8.36005D+00    |proj g|=  1.34082D-03
#
# At iterate   15    f=  8.35969D+00    |proj g|=  1.65182D-02
#
# At iterate   20    f=  8.33126D+00    |proj g|=  1.31457D-01
#
# At iterate   25    f=  8.31214D+00    |proj g|=  1.35582D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     29     32      1     0     0   2.331D-06   8.312D+00
#   F =   8.3121367672623858
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE, 12) - AIC:8604.749417349307
#
#            * * *
#  This problem is unconstrained.
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.36152D+00    |proj g|=  3.50034D-02
#
# At iterate    5    f=  8.36037D+00    |proj g|=  8.43639D-04
#
# At iterate   10    f=  8.35515D+00    |proj g|=  4.20078D-02
#
# At iterate   15    f=  8.34462D+00    |proj g|=  2.84675D-03
#
# At iterate   20    f=  8.34461D+00    |proj g|=  4.14192D-04
#
# At iterate   25    f=  8.34452D+00    |proj g|=  7.44567D-03
#
# At iterate   30    f=  8.32872D+00    |proj g|=  1.02421D-01
#
# At iterate   35    f=  8.27462D+00    |proj g|=  2.48569D-02
#
# At iterate   40    f=  8.27439D+00    |proj g|=  1.18396D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     40     58      1     0     0   1.184D-05   8.274D+00
#   F =   8.2743877643123813
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE, 12) - AIC:8567.716948299003
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.24831D+00    |proj g|=  1.12603D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   1.126D-06   9.248D+00
#   F =   9.2483078337419435
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE, 12) - AIC:9564.75030008917
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.03729D+00    |proj g|=  8.84213D-03
#  This problem is unconstrained.
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      2      5      1     0     0   2.960D-06   9.037D+00
#   F =   9.0372462058260279
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.38580D+00    |proj g|=  7.32729D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   7.327D-06   9.386D+00
#   F =   9.3858001957109316
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# SARIMAX(0, 1, 0)x(0, 1, 0, 12) - AIC:9706.917402365103
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.92101D+00    |proj g|=  1.52121D-01
#
# At iterate    5    f=  8.89884D+00    |proj g|=  1.99903D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      7     11      1     0     0   1.039D-04   8.899D+00
#   F =   8.8988433073234727
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE, 12) - AIC:9205.40397977247
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9
-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     27     36      1     0     0   1.672D-04   8.442D+00
#   F =   8.4417535103305958
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE, 12) - AIC:8742.773129681837
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.31363D+00    |proj g|=  4.82038D-02
#  This problem is unconstrained.
# At iterate    5    f=  8.31109D+00    |proj g|=  1.22158D-03
#
# At iterate   10    f=  8.31109D+00    |proj g|=  3.13471D-04
#
# At iterate   15    f=  8.31100D+00    |proj g|=  8.36079D-03
#
# At iterate   20    f=  8.30204D+00    |proj g|=  9.35021D-02
#
# At iterate   25    f=  8.25941D+00    |proj g|=  8.45180D-03
#
# At iterate   30    f=  8.25935D+00    |proj g|=  2.12852D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     30     34      1     0     0   2.129D-05   8.259D+00
#   F =   8.2593541179891368
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE, 12) - AIC:8552.172158000767
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.31409D+00    |proj g|=  4.78656D-02
#  This problem is unconstrained.
# At iterate    5    f=  8.31115D+00    |proj g|=  6.61275D-04
#
# At iterate   10    f=  8.31115D+00    |proj g|=  1.41847D-03
#
# At iterate   15    f=  8.31110D+00    |proj g|=  1.85897D-03
#
# At iterate   20    f=  8.31110D+00    |proj g|=  2.23032D-04
#
# At iterate   25    f=  8.31094D+00    |proj g|=  7.72752D-03
#
# At iterate   30    f=  8.29820D+00    |proj g|=  6.73260D-02

# %%
# Let's fit this model
mod = sm.tsa.statespace.SARIMAX(train_data,
                                order=SARIMAX_model[AIC.index(min(AIC))][0],
                                seasonal_order=SARIMAX_model[AIC.index(min(AIC))][1],
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()
# Out:
# Data Shape: (730, 1)

# %%
print("Mean of value_1: {}".format(round(value_1.mean()[0],3)))
print("Mean of value_2: {}".format(round(value_2.mean()[0],3)))
# Out:
# Mean of value_1: 7373.111
# Mean of value_2: 7786.299

# %%
print("Variance of value_1: {}".format(round(value_1.var()[0],3)))
print("Variance of value_2: {}".format(round(value_2.var()[0],3)))
# Out:
# Variance of value_1: 4773348.725
# Variance of value_2: 5980501.854

# %%
def adfuller_test(ts, window = 12):
    
    movingAverage = ts.rolling(window).mean()
    movingSTD = ts.rolling(window).std()
    
    plt.figure(figsize = (10,6))
    orig = plt.plot(ts, color='cornflowerblue',
                    label='Original')
    mean = plt.plot(movingAverage, color='firebrick',
                    label='Rolling Mean')
    std = plt.plot(movingSTD, color='limegreen',
                   label='Rolling Std')
    plt.legend(loc = 'upper left')
    plt.title('Rolling Statistics', size = 14)
    plt.show(block=False)
    
    adf = adfuller(ts, autolag='AIC')
    
    print('ADF Statistic: {}'.format(round(adf[0],3)))
    print('p-value: {}'.format(round(adf[1],3)))
    print("##################################")  
    print('Critical Values:')
    
    for key, ts in adf[4].items():
         print('{}: {}'.format(key, round(ts,3)))
    print("##################################")
    
    if adf[0] > adf[4]["5%"]:
        print("ADF > Critical Values")
        print ("Failed to reject null hypothesis, time series is non-stationary.")
    else:
        print("ADF < Critical Values")
        print ("Reject null hypothesis, time series is stationary.")
        
adfuller_test(df, window = 12)
# Out:
# ADF Statistic: -4.068
# p-value: 0.001
# ##################################
# Critical Values:
# 1%: -3.44
# 5%: -2.866
# 10%: -2.569
# ##################################
# ADF < Critical Values
# Reject null hypothesis, time series is stationary.

# %%
df_log_scaled = df
df_log_scaled['berat'] = boxcox(df_log_scaled['berat'], lmbda=0.0)
plt.figure(figsize = (10,6))
plt.plot(df_log_scaled, color = 'cornflowerblue')
plt.xlabel('tanggal', size = 12)
plt.ylabel('Cargo Production', size = 12)
plt.title("After Logarithmic Transformation", size = 14)
plt.show()

# %%
moving_avg = df_log_scaled.rolling(window=12).mean()
df_log_scaled_ma = df_log_scaled - moving_avg
df_log_scaled_ma.dropna(inplace=True)
plt.figure(figsize = (10,6))
plt.plot(df_log_scaled_ma, color = 'cornflowerblue')
plt.xlabel('tanggal', size = 12)
plt.ylabel('Cargo Production', size = 12)
plt.title("After Moving Average", size = 14)
plt.show()

# %%
df_log_scaled_ma_ed = df_log_scaled_ma.ewm(halflife=12, min_periods=0, adjust=True).mean()
df_lsma_sub_df_lsma_ed = df_log_scaled_ma - df_log_scaled_ma_ed
plt.figure(figsize = (10,6))
plt.plot(df_lsma_sub_df_lsma_ed - df_log_scaled_ma_ed, color='cornflowerblue')
plt.xlabel('tanggal', size = 12)
plt.ylabel('Cargo Production', size = 12)
plt.title("After Exponential Decay Transformation", size = 14)
plt.show()

# %%
adfuller_test(df_lsma_sub_df_lsma_ed, window = 12)
# Out:
# ADF Statistic: -8.361
# p-value: 0.0
# ##################################
# Critical Values:
# 1%: -3.44
# 5%: -2.866
# 10%: -2.569
# ##################################
# ADF < Critical Values
# Reject null hypothesis, time series is stationary.

# %%
rcParams['figure.figsize']=10,8
df_seasonal_decompose = seasonal_decompose(df_lsma_sub_df_lsma_ed, model='duplicative')
df_seasonal_decompose.plot()
plt.show()

# %%
auto_c_f = acf(df_lsma_sub_df_lsma_ed, nlags=20)
partial_auto_c_f = pacf(df_lsma_sub_df_lsma_ed, nlags=20, method='ols')

fig, axs = plt.subplots(1, 2, figsize =(12,5))

plt.subplot(121)
plt.plot(auto_c_f)
plt.axhline(y=0, linestyle='--', color='limegreen')
plt.axhline(y=-1.96/np.sqrt(len(df_lsma_sub_df_lsma_ed)),
            linestyle='--', color='firebrick')
plt.axhline(y=1.96/np.sqrt(len(df_lsma_sub_df_lsma_ed)),
            linestyle='--', color='firebrick')
plt.title('Autocorrelation Function', size = 14)            

plt.subplot(122)
plt.plot(partial_auto_c_f)
plt.axhline(y=0, linestyle='--', color='limegreen')
plt.axhline(y=-1.96/np.sqrt(len(df_lsma_sub_df_lsma_ed)),
            linestyle='--', color='firebrick')
plt.axhline(y=1.96/np.sqrt(len(df_lsma_sub_df_lsma_ed)),
            linestyle='--', color='firebrick')
plt.title('Partial Autocorrelation Function', size = 14)
            
plt.tight_layout()

# %%
persistence_df = concat([values.shift(1), values], axis=1)
persistence_df.columns = ['t-1', 't+1']
per_values = persistence_df.values

train = per_values[1:len(per_values)-10] 
test = per_values[len(per_values)-10:]

X_train, y_train = train[:,0], train[:,1]
X_test, y_test = test[:,0], test[:,1]

def persistence(x):
    return x

predictions = []
for i in X_test:
    y_pred = persistence(i)
    predictions.append(y_pred)

persistence_score = mean_squared_error(y_test, predictions)
print('Persistence MSE: {}'.format(round(persistence_score,4)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/8s/cbvp0h214r37v9h2fyhm_lrw0000gn/T/ipykernel_6744/3848324641.py in <module>
# ----> 1 persistence_df = concat([values.shift(1), values], axis=1)
#       2 persistence_df.columns = ['t-1', 't+1']
#       3 per_values = persistence_df.values
#       4
#       5 train = per_values[1:len(per_values)-10]
#
# NameError: name 'values' is not defined

# %%
# Forecast
n_periods = 24
fc, confint = model.predict(n_periods=n_periods, return_conf_int=True)
index_of_fc = np.arange(len(df.berat), len(df.berat)+n_periods)

# make series for plotting purpose
fc_series = pd.Series(fc, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.plot(df.berat)
plt.plot(fc_series, color='darkgreen')
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("Final Forecast of Usage")
plt.show()
